# %% [markdown]
# Credit to Lori Garzio for the soucre code in calculating the mixed layer depth on her GitHub - https://github.com/lgarzio/gliders/blob/master/analyses/calculate_mld.py

# %%
#!/usr/bin/env python

"""
Author: Lori Garzio on 1/11/2022
Last modified: 11/8/2023
Modified from code from Sam Coakley following theory from Carvalho et al 2016 https://doi.org/10.1002/2016GL071205
Calculate Mixed Layer Depth for glider profiles using density and pressure, then add the MLD variable to the .nc file.
The dataset provided must have 'time' or 'profile_time' as the only coordinate in order to convert the dataset to a
dataframe properly
"""

import os
import datetime as dt
import xarray as xr
import numpy as np
import pandas as pd
import gsw
import matplotlib.pyplot as plt
# import functions.common as cf
# import functions.mixed_layer_depth as mldfunc
plt.rcParams.update({'font.size': 14})
pd.set_option('display.width', 320, "display.max_columns", 20)  # for display in pycharm console

# %%
#! /usr/bin/env python3

"""
Author: Lori Garzio on 10/23/2023
Last modified: 10/26/2023
"""
import numpy as np
import pandas as pd
import cmocean as cmo


def depth_bin(dataframe, depth_var='depth', depth_min=0, depth_max=None, stride=1):
    """
    Written by Mike Smith
    :param dataframe: depth profile in the form of a pandas dataframe
    :param depth_var: the name of the depth variable in the dataframe
    :param depth_min: the shallowest bin depth
    :param depth_max: the deepest bin depth
    :param stride: the amount of space between each bin
    :return: pandas dataframe where data has been averaged into specified depth bins
    """
    depth_max = depth_max or dataframe[depth_var].max()
    print(dataframe[depth_var])

    bins = np.arange(depth_min, depth_max+stride, stride)  # Generate array of depths you want to bin at
    cut = pd.cut(dataframe[depth_var], bins)  # Cut/Bin the dataframe based on the bins variable we just generated
    binned_df = dataframe.groupby(cut, observed=False).mean()  # Groupby the cut and do the mean
    return binned_df


def glider_extent(lats, lons):
    """
    Calculate the map extents for plotting a glider deployment
    """
    extent = [np.nanmin(lons) - 2, np.nanmax(lons) + 2,
              np.nanmin(lats) - 1.5, np.nanmax(lats) + 1.5]

    return extent

# %%
#! /usr/bin/env python3

import numpy as np


def gap(prange):
    """
    :param prange: pressure range of the profile
    :return: the maximum allowable data gap for the profile
    """
    if prange < 20:
        gap_threshold = 8
    elif 20 <= prange < 50:
        gap_threshold = 10
    elif 50 <= prange < 200:
        gap_threshold = 25
    elif 200 <= prange < 500:
        gap_threshold = 50
    else:
        gap_threshold = 75

    return gap_threshold


def profile_mld(df, mld_var='density', zvar='pressure', qi_threshold=0.5):
    """
    Written by Sam Coakley and Lori Garzio, Jan 2022
    Calculates the Mixed Layer Depth (MLD) for a single profile as the depth of max Brunt‐Vaisala frequency squared
    (N**2) from Carvalho et al 2016 (https://doi.org/10.1002/2016GL071205). Calculates a Quality Index to determine
    if the water column is well-mixed, hence calculating MLD is not appropriate and the function will return
    MLD = np.nan, from Lorbacher et al, 2006 doi:10.1029/2003JC002157. When "QI > 0.8 a well defined MLD results.
    For QI in the range 0.5– 0.8, increased uncertainty of the profile interpretation becomes evident and with
    QI < 0.5 no mixed layer interpretation is possible." (from Section 3.4)
    :param df: depth profile in the form of a pandas dataframe
    :param mld_var: the name of the variable for which MLD is calculated, default is 'density'
    :param zvar: the name of the depth variable in the dataframe, default is 'pressure'
    :param qi_threshold: quality index threshold for determining well-mixed water, default is 0.5
    :return: the depth of the mixed layer in the units of zvar and the max buoyancy frequency in units of s-2
    """
    df.dropna(subset=[mld_var], inplace=True)
    pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
    if len(df) < 5:  # if there are <5 data bins, don't calculate MLD
        mld = np.nan
        maxN2 = np.nan
        qi = np.nan
    elif np.sum(~np.isnan(pN2)) < 3:  # if there are <3 values calculated for pN2, don't calculate MLD
        mld = np.nan
        maxN2 = np.nan
        qi = np.nan
    elif np.nanmax(np.diff(df[zvar])) > gap(np.nanmax(df[zvar]) - np.nanmin(df[zvar])):
        # if there is a gap in the profile that exceeds the defined threshold, don't calculate MLD
        mld = np.nan
        maxN2 = np.nan
        qi = np.nan
    else:
        pressure_range = [np.nanmin(df[zvar]), np.nanmax(df[zvar])]

        maxN2 = np.nanmax(pN2)
        mld_idx = np.where(pN2 == maxN2)[0][0]

        # if the code finds the first or last data point to be the max pN2, return nan
        if np.logical_or(mld_idx == 0, mld_idx == len(df) - 1):
            mld = np.nan
            maxN2 = np.nan
            qi = np.nan
        else:
            mld = np.nanmean([df[zvar][mld_idx], df[zvar][mld_idx + 1]])

            if mld < 5:
                # if MLD is <5, return nan
                mld = np.nan
                maxN2 = np.nan
                qi = np.nan
            elif np.logical_or(mld < pressure_range[0] + 2, mld > pressure_range[1] - 2):
                # if MLD is within 2 dbar of the top or bottom of the profile, return nan
                mld = np.nan
                maxN2 = np.nan
                qi = np.nan
            else:
                if qi_threshold:
                    # find MLD  1.5
                    mld15 = mld * 1.5
                    mld15_idx = np.argmin(np.abs(df[zvar] - mld15))

                    # Calculate Quality index (QI) from Lorbacher et al, 2006 doi:10.1029/2003JC002157
                    surface_mld_values = df[mld_var][0:mld_idx]  # values from the surface to MLD
                    surface_mld15_values = df[mld_var][0:mld15_idx]  # values from the surface to MLD * 1.5

                    qi = 1 - (np.std(surface_mld_values - np.nanmean(surface_mld_values)) /
                              np.std(surface_mld15_values - np.nanmean(surface_mld15_values)))

                    if qi < qi_threshold:
                        # if the Quality Index is < the threshold, this indicates well-mixed water so don't return MLD
                        mld = np.nan
                        maxN2 = np.nan

    return mld, maxN2, qi

# %%
def main(fname, timevar, plots, mldvar, zvar):
    mld = np.array([], dtype='float32')
    max_n2 = np.array([], dtype='float32')

    savefile = f'{fname.split(".nc")[0]}_mld.nc'

    ds = xr.open_dataset(fname)
    ds = ds.sortby(ds.time)
    deploy = ds.title

    df = ds.to_dataframe()

    # remove data (pressure plus the variable you're using to calculate MLD) that's collected at the surface (< 1 dbar)
    df.loc[df.pressure < 1, ['pressure', mldvar]] = np.nan
    grouped = df.groupby(timevar, dropna=False)

    if plots:
        plots = os.path.join(plots, 'mld_analysis', deploy)
        os.makedirs(plots, exist_ok=True)

    for group in grouped:
        # Create temporary dataframe to interpolate to dz m depths
        ll = len(group[1])
        kwargs = {'depth_var': zvar}
        temp_df1 = group[1][[mldvar, zvar, 'temperature']].dropna(how='all')
        if len(temp_df1) == 0:
            mldx = np.repeat(np.nan, ll)
            max_n2x = np.repeat(np.nan, ll)
        else:
            temp_df = depth_bin(temp_df1, **kwargs)
            temp_df.dropna(subset=[mldvar], inplace=True)
            temp_df.index.name = f'{zvar}_bins'
            temp_df.reset_index(inplace=True)
            if len(temp_df) == 0:
                mldx = np.repeat(np.nan, ll)
                max_n2x = np.repeat(np.nan, ll)
                qi = 'MLD not calculated'
            else:
                # calculate profile's pressure range
                pressure_range = (np.nanmax(temp_df[zvar]) - np.nanmin(temp_df[zvar]))

                if pressure_range < 5:
                    # if the profile spans <5 dbar, don't calculate MLD
                    mldx = np.repeat(np.nan, ll)
                    max_n2x = np.repeat(np.nan, ll)
                    qi = 'MLD not calculated'

                else:
                    kwargs = {'zvar': zvar}
                    mldx, N2, qi = profile_mld(temp_df, **kwargs)
                    mldx = np.repeat(mldx, ll)
                    max_n2x = np.repeat(N2, ll)

            if plots:
                try:
                    tstr = group[0].strftime("%Y-%m-%dT%H%M%SZ")
                except AttributeError:
                    tstr = pd.to_datetime(np.nanmin(group[1].time)).strftime("%Y-%m-%dT%H%M%SZ")
                # plot temperature
                fig, ax = plt.subplots(figsize=(8, 10))
                ax.scatter(temp_df['temperature'], temp_df[zvar])

                ax.invert_yaxis()
                ax.set_ylabel('Pressure (dbar)')
                ax.set_xlabel('temperature')

                ax.axhline(y=np.unique(mldx), ls='--', c='k')

                sfile = os.path.join(plots, f'temperature_{tstr}.png')
                plt.savefig(sfile, dpi=300)
                plt.close()

                # plot density
                fig, ax = plt.subplots(figsize=(8, 10))
                ax.scatter(temp_df['density'], temp_df[zvar])

                ax.invert_yaxis()
                ax.set_ylabel('Pressure (dbar)')
                ax.set_xlabel('density')
                ax.set_title(f'QI = {qi}\nN2 = {np.unique(max_n2x)[0]}')

                ax.axhline(y=np.unique(mldx), ls='--', c='k')

                sfile = os.path.join(plots, f'density{tstr}.png')
                plt.savefig(sfile, dpi=300)
                plt.close()

        mld = np.append(mld, mldx)
        max_n2 = np.append(max_n2, max_n2x)

    # add mld to the dataset
    mld_min = np.nanmin(mld)
    mld_max = np.nanmax(mld)
    attrs = {
        'actual_range': np.array([mld_min, mld_max]),
        'ancillary_variables': [mldvar, zvar],
        'observation_type': 'calculated',
        'units': ds[zvar].units,
        'comment': 'Mixed Layer Depth calculated as the depth of max Brunt‐Vaisala frequency squared (N**2) '
                   'from Carvalho et al 2016 (https://doi.org/10.1002/2016GL071205)',
        'long_name': 'Mixed Layer Depth'
        }
    da = xr.DataArray(mld, coords=ds[mldvar].coords, dims=ds[mldvar].dims,
                      name='mld_dbar', attrs=attrs)
    ds['mld_dbar'] = da

    # calculate MLD in meters
    mld_meters = gsw.z_from_p(-ds.mld_dbar.values, ds.latitude.values)

    attrs = {
        'actual_range': np.array([np.nanmin(mld_meters), np.nanmax(mld_meters)]),
        'observation_type': 'calculated',
        'units': 'm',
        'comment': 'Mixed Layer Depth calculated as the depth of max Brunt‐Vaisala frequency squared (N**2) from '
                   'Carvalho et al 2016 (https://doi.org/10.1002/2016GL071205). Calculated from MLD in dbar and latitude using gsw.z_from_p',
        'long_name': 'Mixed Layer Depth'
    }
    da = xr.DataArray(mld_meters, coords=ds.mld_dbar.coords, dims=ds.mld_dbar.dims,
                      name='mld', attrs=attrs)
    ds['mld'] = da

    # add maximum buoyancy frequency N2 (measure of stratification strength) to the dataset
    n2_min = np.nanmin(max_n2)
    n2_max = np.nanmax(max_n2)
    attrs = {
        'actual_range': np.array([n2_min, n2_max]),
        'ancillary_variables': [mldvar, zvar],
        'observation_type': 'calculated',
        'units': 's-2',
        'comment': 'Maximum Brunt‐Vaisala frequency squared (N**2) for each profile used to calculate Mixed Layer Depth '
                   'from Carvalho et al 2016 (https://doi.org/10.1002/2016GL071205). This can be used as a measurement '
                   'for stratification strength',
        'long_name': 'Maximum Buoyancy Frequency'
    }
    da = xr.DataArray(max_n2, coords=ds[mldvar].coords, dims=ds[mldvar].dims,
                      name='max_n2', attrs=attrs)
    ds['max_n2'] = da

    ds.to_netcdf(savefile)

# %%
if __name__ == '__main__':
    ncfile = '/Users/nixo1/Desktop/MLD_results/ru39-20240215T1646-profile-sci-delayed_slice2.nc'  # striper-20170907T1430.nc ru30-20180705T1825.nc
    time_variable = 'profile_time'  # time variable on which groups are generated (e.g. profile_time)
    generate_plots = False # '/Users/garzio/Documents/rucool/Saba/gliderdata/2023/ru39-20230817T1520/delayed/ncei'  # False or save_directory e.g. '/Users/garzio/Documents/rucool/Saba/gliderdata/plots'
    mldvar = 'density'  # variable used to calculate MLD
    zvar = 'pressure'  # pressure variable
    main(ncfile, time_variable, generate_plots, mldvar, zvar)
# Out:
# row
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 197    54.360001
# 198    54.770000
# 199    55.189999
# 200    55.439999
# 201    55.470001
# Name: pressure, Length: 202, dtype: float32
# row
# 202    55.470001
# 203    55.430000
# 204    55.459999
# 205    55.470001
# 206    55.380001
#          ...
# 387     2.830000
# 388     2.570000
# 389     2.430000
# 390     2.260000
# 391     2.220000
# Name: pressure, Length: 190, dtype: float32
# row
# 392     2.220000
# 393     2.260000
# 394     2.320000
# 395     2.460000
# 396     2.730000
#          ...
# 582    54.730000
# 583    54.860001
# 584    55.070000
# 585    55.259998
# 586    55.290001
# Name: pressure, Length: 195, dtype: float32
# row
# 587    55.290001
# 588    55.209999
# 589    55.070000
# 590    54.840000
# 591    54.590000
#          ...
# 778     2.710000
# 779     2.510000
# 780     2.260000
# 781     2.110000
# 782     2.040000
# Name: pressure, Length: 196, dtype: float32
# row
# 783     2.040000
# 784     2.060000
# 785     2.140000
# 786     2.290000
# 787     2.440000
#          ...
# 974    54.680000
# 975    55.060001
# 976    55.389999
# 977    55.500000
# 978    55.549999
# Name: pressure, Length: 196, dtype: float32
# row
# 979     55.549999
# 980     55.549999
# 981     55.549999
# 982     55.470001
# 983     55.279999
#           ...
# 1171     3.110000
# 1172     2.830000
# 1173     2.630000
# 1174     2.490000
# 1175     2.420000
# Name: pressure, Length: 197, dtype: float32
# row
# 1176     2.420000
# 1177     2.460000
# 1178     2.560000
# 1179     2.780000
# 1180     2.970000
#           ...
# 1370    55.259998
# 1371    55.549999
# 1372    56.040001
# 1373    56.410000
# 1374    56.430000
# Name: pressure, Length: 199, dtype: float32
# row
# 1375    56.430000
# 1376    56.200001
# 1377    56.009998
# 1378    56.160000
# 1379    56.270000
#           ...
# 1569     2.610000
# 1570     2.490000
# 1571     2.390000
# 1572     2.380000
# 1573     2.320000
# Name: pressure, Length: 199, dtype: float32
# row
# 1574     2.320000
# 1575     2.380000
# 1576     2.580000
# 1577     2.800000
# 1578     3.060000
#           ...
# 1764    55.560001
# 1765    55.580002
# 1766    55.849998
# 1767    56.250000
# 1768    56.419998
# Name: pressure, Length: 195, dtype: float32
# row
# 1769    56.419998
# 1770    56.259998
# 1771    55.919998
# 1772    55.709999
# 1773    55.709999
#           ...
# 1965     2.420000
# 1966     2.290000
# 1967     2.050000
# 1968     1.990000
# 1969     1.870000
# Name: pressure, Length: 201, dtype: float32
# row
# 1970     1.870000
# 1971     1.900000
# 1972     2.000000
# 1973     2.210000
# 1974     2.440000
#           ...
# 2165    55.880001
# 2166    55.750000
# 2167    55.759998
# 2168    55.889999
# 2169    55.970001
# Name: pressure, Length: 200, dtype: float32
# row
# 2170    55.970001
# 2171    55.770000
# 2172    55.419998
# 2173    55.080002
# 2174    54.910000
#           ...
# 2367     2.970000
# 2368     2.720000
# 2369     2.530000
# 2370     2.320000
# 2371     2.280000
# Name: pressure, Length: 202, dtype: float32
# row
# 2372     2.280000
# 2373     2.290000
# 2374     2.430000
# 2375     2.590000
# 2376     2.780000
#           ...
# 2562    53.980000
# 2563    54.330002
# 2564    54.660000
# 2565    54.810001
# 2566    54.830002
# Name: pressure, Length: 195, dtype: float32
# row
# 2567    54.830002
# 2568    54.770000
# 2569    54.810001
# 2570    54.810001
# 2571    54.709999
#           ...
# 2755     3.280000
# 2756     3.110000
# 2757     2.900000
# 2758     2.770000
# 2759     2.690000
# Name: pressure, Length: 193, dtype: float32
# row
# 2760     2.690000
# 2761     2.690000
# 2762     2.700000
# 2763     2.800000
# 2764     3.040000
#           ...
# 2941    53.270000
# 2942    53.439999
# 2943    53.779999
# 2944    54.080002
# 2945    54.209999
# Name: pressure, Length: 186, dtype: float32
# row
# 2946    54.209999
# 2947    54.130001
# 2948    54.029999
# 2949    53.889999
# 2950    53.740002
#           ...
# 3137     2.800000
# 3138     2.510000
# 3139     2.270000
# 3140     2.150000
# 3141     2.080000
# Name: pressure, Length: 196, dtype: float32
# row
# 3142     2.080000
# 3143     2.200000
# 3144     2.380000
# 3145     2.680000
# 3146     2.920000
#           ...
# 3329    53.610001
# 3330    53.669998
# 3331    53.770000
# 3332    53.849998
# 3333    53.869999
# Name: pressure, Length: 192, dtype: float32
# row
# 3334    53.869999
# 3335    53.709999
# 3336    53.490002
# 3337    53.270000
# 3338    53.110001
#           ...
# 3518     2.990000
# 3519     2.800000
# 3520     2.560000
# 3521     2.440000
# 3522     2.350000
# Name: pressure, Length: 189, dtype: float32
# row
# 3523     2.350000
# 3524     2.410000
# 3525     2.470000
# 3526     2.640000
# 3527     2.860000
#           ...
# 3706    53.119999
# 3707    53.090000
# 3708    53.349998
# 3709    53.759998
# 3710    54.020000
# Name: pressure, Length: 188, dtype: float32
# row
# 3711    54.020000
# 3712    53.919998
# 3713    53.560001
# 3714    53.230000
# 3715    53.110001
#           ...
# 3897     2.770000
# 3898     2.570000
# 3899     2.370000
# 3900     2.350000
# 3901     2.290000
# Name: pressure, Length: 191, dtype: float32
# row
# 3902     2.290000
# 3903     2.340000
# 3904     2.470000
# 3905     2.700000
# 3906     2.910000
#           ...
# 4085    53.139999
# 4086    53.099998
# 4087    53.049999
# 4088    53.150002
# 4089    53.169998
# Name: pressure, Length: 188, dtype: float32
# row
# 4090    53.169998
# 4091    52.970001
# 4092    52.509998
# 4093    52.139999
# 4094    51.959999
#           ...
# 4271     2.920000
# 4272     2.670000
# 4273     2.460000
# 4274     2.290000
# 4275     2.230000
# Name: pressure, Length: 186, dtype: float32
# row
# 4276     2.230000
# 4277     2.240000
# 4278     2.330000
# 4279     2.460000
# 4280     2.710000
#           ...
# 4458    52.500000
# 4459    52.700001
# 4460    52.980000
# 4461    53.209999
# 4462    53.299999
# Name: pressure, Length: 187, dtype: float32
# row
# 4463    53.299999
# 4464    53.220001
# 4465    53.110001
# 4466    52.980000
# 4467    52.910000
#           ...
# 4648     2.560000
# 4649     2.350000
# 4650     2.180000
# 4651     2.090000
# 4652     2.020000
# Name: pressure, Length: 190, dtype: float32
# row
# 4653     2.020000
# 4654     2.060000
# 4655     2.130000
# 4656     2.280000
# 4657     2.500000
#           ...
# 4838    53.009998
# 4839    52.869999
# 4840    52.869999
# 4841    53.000000
# 4842    53.220001
# Name: pressure, Length: 190, dtype: float32
# row
# 4843    53.220001
# 4844    53.169998
# 4845    52.740002
# 4846    52.110001
# 4847    51.750000
#           ...
# 5021     2.780000
# 5022     2.510000
# 5023     2.340000
# 5024     2.100000
# 5025     2.030000
# Name: pressure, Length: 183, dtype: float32
# row
# 5026     2.030000
# 5027     2.080000
# 5028     2.150000
# 5029     2.310000
# 5030     2.490000
#           ...
# 5212    52.660000
# 5213    52.779999
# 5214    52.959999
# 5215    53.220001
# 5216    53.240002
# Name: pressure, Length: 191, dtype: float32
# row
# 5217    53.240002
# 5218    53.099998
# 5219    52.910000
# 5220    52.840000
# 5221    52.720001
#           ...
# 5424     1.860000
# 5425     1.530000
# 5426     1.090000
# 5427          NaN
# 5428          NaN
# Name: pressure, Length: 212, dtype: float32
# row
# 5429          NaN
# 5430          NaN
# 5431          NaN
# 5432          NaN
# 5433          NaN
#           ...
# 5621    52.480000
# 5622    52.680000
# 5623    53.110001
# 5624    53.459999
# 5625    53.599998
# Name: pressure, Length: 197, dtype: float32
# row
# 5626    53.599998
# 5627    53.439999
# 5628    53.209999
# 5629    52.990002
# 5630    52.910000
#           ...
# 5789     3.210000
# 5790     3.000000
# 5791     2.780000
# 5792     2.680000
# 5793     2.620000
# Name: pressure, Length: 168, dtype: float32
# row
# 5794     2.620000
# 5795     2.640000
# 5796     2.780000
# 5797     2.940000
# 5798     3.250000
#           ...
# 5974    52.939999
# 5975    52.950001
# 5976    52.889999
# 5977    53.049999
# 5978    53.220001
# Name: pressure, Length: 185, dtype: float32
# row
# 5979    53.220001
# 5980    53.220001
# 5981    52.959999
# 5982    52.709999
# 5983    52.470001
#           ...
# 6146     2.380000
# 6147     2.090000
# 6148     1.940000
# 6149     1.860000
# 6150     1.840000
# Name: pressure, Length: 172, dtype: float32
# row
# 6151     1.840000
# 6152     1.850000
# 6153     1.950000
# 6154     2.120000
# 6155     2.310000
#           ...
# 6327    53.049999
# 6328    53.070000
# 6329    52.950001
# 6330    53.040001
# 6331    53.220001
# Name: pressure, Length: 181, dtype: float32
# row
# 6332    53.220001
# 6333    53.220001
# 6334    52.830002
# 6335    52.360001
# 6336    52.130001
#           ...
# 6502     3.130000
# 6503     2.990000
# 6504     2.800000
# 6505     2.660000
# 6506     2.570000
# Name: pressure, Length: 175, dtype: float32
# row
# 6507     2.570000
# 6508     2.640000
# 6509     2.760000
# 6510     2.920000
# 6511     3.070000
#           ...
# 6685    52.299999
# 6686    52.470001
# 6687    52.759998
# 6688    53.060001
# 6689    53.240002
# Name: pressure, Length: 183, dtype: float32
# row
# 6690    53.240002
# 6691    53.160000
# 6692    53.029999
# 6693    53.000000
# 6694    53.029999
#           ...
# 6862     2.930000
# 6863     2.690000
# 6864     2.570000
# 6865     2.420000
# 6866     2.380000
# Name: pressure, Length: 177, dtype: float32
# row
# 6867     2.380000
# 6868     2.450000
# 6869     2.620000
# 6870     2.880000
# 6871     3.150000
#           ...
# 7051    52.509998
# 7052    52.740002
# 7053    52.959999
# 7054    53.189999
# 7055    53.240002
# Name: pressure, Length: 189, dtype: float32
# row
# 7056    53.240002
# 7057    53.130001
# 7058    52.830002
# 7059    52.549999
# 7060    52.470001
#           ...
# 7230     2.680000
# 7231     2.370000
# 7232     2.200000
# 7233     2.090000
# 7234     2.060000
# Name: pressure, Length: 179, dtype: float32
# row
# 7235     2.060000
# 7236     2.090000
# 7237     2.240000
# 7238     2.360000
# 7239     2.600000
#           ...
# 7409    52.150002
# 7410    52.520000
# 7411    52.790001
# 7412    52.939999
# 7413    52.959999
# Name: pressure, Length: 179, dtype: float32
# row
# 7414    52.959999
# 7415    52.840000
# 7416    52.660000
# 7417    52.610001
# 7418    52.639999
#           ...
# 7581     3.640000
# 7582     3.410000
# 7583     3.230000
# 7584     3.190000
# 7585     3.160000
# Name: pressure, Length: 172, dtype: float32
# row
# 7586     3.160000
# 7587     3.250000
# 7588     3.310000
# 7589     3.450000
# 7590     3.590000
#           ...
# 7755    52.150002
# 7756    52.270000
# 7757    52.450001
# 7758    52.590000
# 7759    52.689999
# Name: pressure, Length: 174, dtype: float32
# row
# 7760    52.689999
# 7761    52.610001
# 7762    52.500000
# 7763    52.400002
# 7764    52.320000
#           ...
# 7939     2.810000
# 7940     2.690000
# 7941     2.600000
# 7942     2.550000
# 7943     2.530000
# Name: pressure, Length: 184, dtype: float32
# row
# 7944     2.530000
# 7945     2.620000
# 7946     2.720000
# 7947     2.970000
# 7948     3.220000
#           ...
# 8124    52.840000
# 8125    52.959999
# 8126    53.080002
# 8127    53.139999
# 8128    53.209999
# Name: pressure, Length: 185, dtype: float32
# row
# 8129    53.209999
# 8130    53.160000
# 8131    52.939999
# 8132    52.630001
# 8133    52.389999
#           ...
# 8300     2.550000
# 8301     2.380000
# 8302     2.200000
# 8303     2.150000
# 8304     2.130000
# Name: pressure, Length: 176, dtype: float32
# row
# 8305     2.130000
# 8306     2.220000
# 8307     2.300000
# 8308     2.470000
# 8309     2.730000
#           ...
# 8481    51.470001
# 8482    51.720001
# 8483    52.090000
# 8484    52.470001
# 8485    52.619999
# Name: pressure, Length: 181, dtype: float32
# row
# 8486    52.619999
# 8487    52.590000
# 8488    52.500000
# 8489    52.450001
# 8490    52.439999
#           ...
# 8654     3.060000
# 8655     2.800000
# 8656     2.550000
# 8657     2.390000
# 8658     2.290000
# Name: pressure, Length: 173, dtype: float32
# row
# 8659     2.290000
# 8660     2.290000
# 8661     2.350000
# 8662     2.530000
# 8663     2.710000
#           ...
# 8849    52.250000
# 8850    52.509998
# 8851    52.779999
# 8852    53.029999
# 8853    53.099998
# Name: pressure, Length: 195, dtype: float32
# row
# 8854    53.099998
# 8855    53.040001
# 8856    52.880001
# 8857    52.740002
# 8858    52.580002
#           ...
# 9031     2.460000
# 9032     2.250000
# 9033     2.150000
# 9034     2.090000
# 9035     2.080000
# Name: pressure, Length: 182, dtype: float32
# row
# 9036     2.080000
# 9037     2.150000
# 9038     2.330000
# 9039     2.490000
# 9040     2.700000
#           ...
# 9218    52.009998
# 9219    52.220001
# 9220    52.480000
# 9221    52.619999
# 9222    52.639999
# Name: pressure, Length: 187, dtype: float32
# row
# 9223    52.639999
# 9224    52.480000
# 9225    52.340000
# 9226    52.189999
# 9227    52.110001
#           ...
# 9390     3.300000
# 9391     3.060000
# 9392     2.930000
# 9393     2.780000
# 9394     2.760000
# Name: pressure, Length: 172, dtype: float32
# row
# 9395     2.760000
# 9396     2.810000
# 9397     2.940000
# 9398     3.090000
# 9399     3.310000
#           ...
# 9568    51.590000
# 9569    51.740002
# 9570    52.070000
# 9571    52.439999
# 9572    52.709999
# Name: pressure, Length: 178, dtype: float32
# row
# 9573    52.709999
# 9574    52.680000
# 9575    52.610001
# 9576    52.619999
# 9577    52.669998
#           ...
# 9747     3.040000
# 9748     2.800000
# 9749     2.570000
# 9750     2.480000
# 9751     2.410000
# Name: pressure, Length: 179, dtype: float32
# row
# 9752     2.410000
# 9753     2.460000
# 9754     2.520000
# 9755     2.750000
# 9756     2.930000
#           ...
# 9931    52.570000
# 9932    52.580002
# 9933    52.520000
# 9934    52.580002
# 9935    52.650002
# Name: pressure, Length: 184, dtype: float32
# row
# 9936     52.650002
# 9937     52.619999
# 9938     52.389999
# 9939     52.080002
# 9940     51.830002
#            ...
# 10105     2.590000
# 10106     2.380000
# 10107     2.250000
# 10108     2.190000
# 10109     2.130000
# Name: pressure, Length: 174, dtype: float32
# row
# 10110     2.130000
# 10111     2.130000
# 10112     2.230000
# 10113     2.400000
# 10114     2.710000
#            ...
# 10280    51.790001
# 10281    51.799999
# 10282    51.910000
# 10283    52.110001
# 10284    52.270000
# Name: pressure, Length: 175, dtype: float32
# row
# 10285    52.270000
# 10286    52.160000
# 10287    51.880001
# 10288    51.660000
# 10289    51.590000
#            ...
# 10450     3.070000
# 10451     2.820000
# 10452     2.580000
# 10453     2.450000
# 10454     2.390000
# Name: pressure, Length: 170, dtype: float32
# row
# 10455     2.390000
# 10456     2.440000
# 10457     2.500000
# 10458     2.650000
# 10459     2.840000
#            ...
# 10627    51.279999
# 10628    51.509998
# 10629    51.660000
# 10630    51.840000
# 10631    51.970001
# Name: pressure, Length: 177, dtype: float32
# row
# 10632    51.970001
# 10633    51.970001
# 10634    51.860001
# 10635    51.840000
# 10636    51.810001
#            ...
# 10805     2.220000
# 10806     1.920000
# 10807     1.700000
# 10808     1.570000
# 10809     1.510000
# Name: pressure, Length: 178, dtype: float32
# row
# 10810     1.51
# 10811     1.53
# 10812     1.60
# 10813     1.69
# 10814     1.89
# 10815     2.08
# 10816     2.34
# 10817     2.56
# 10818     2.75
# 10819     2.91
# 10820     3.07
# 10821     3.25
# 10822     3.47
# 10823     3.69
# 10824     3.89
# 10825     4.11
# 10826     4.28
# 10827     4.51
# 10828     4.74
# 10829     5.07
# 10830     5.35
# 10831     5.65
# 10832     5.92
# 10833     6.22
# 10834     6.53
# 10835     6.74
# 10836     7.03
# 10837     7.35
# 10838     7.62
# 10839     7.91
# 10840     8.24
# 10841     8.46
# 10842     8.72
# 10843     8.97
# 10844     9.30
# 10845     9.56
# 10846     9.84
# 10847    10.10
# 10848    10.36
# 10849    10.45
# 10850    10.54
# 10851    10.56
# Name: pressure, dtype: float32
# row
# 10852    10.56
# 10853    10.54
# 10854    10.40
# 10855    10.22
# 10856    10.00
# 10857     9.74
# 10858     9.48
# 10859     9.23
# 10860     8.99
# 10861     8.75
# 10862     8.47
# 10863     8.18
# 10864     7.94
# 10865     7.67
# 10866     7.40
# 10867     7.09
# 10868     6.80
# 10869     6.48
# 10870     6.22
# 10871     5.91
# 10872     5.67
# 10873     5.39
# 10874     5.15
# 10875     4.87
# 10876     4.57
# 10877     4.29
# 10878     3.96
# 10879     3.68
# 10880     3.41
# 10881     3.11
# 10882     2.76
# 10883     2.44
# 10884     2.12
# 10885     1.88
# 10886     1.59
# 10887     1.27
# 10888      NaN
# 10889      NaN
# Name: pressure, dtype: float32
# row
# 10890          NaN
# 10891          NaN
# 10892          NaN
# 10893          NaN
# 10894          NaN
#            ...
# 11097    52.540001
# 11098    52.730000
# 11099    52.930000
# 11100    53.110001
# 11101    53.220001
# Name: pressure, Length: 212, dtype: float32
# row
# 11102    53.220001
# 11103    53.189999
# 11104    53.099998
# 11105    52.950001
# 11106    52.700001
#            ...
# 11276     3.150000
# 11277     2.880000
# 11278     2.730000
# 11279     2.660000
# 11280     2.630000
# Name: pressure, Length: 179, dtype: float32
# C:\Users\nixo1\AppData\Local\Temp\ipykernel_22600\3273644669.py:41: RuntimeWarning: invalid value encountered in sqrt
#   pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
# C:\Users\nixo1\AppData\Local\Temp\ipykernel_22600\3273644669.py:41: RuntimeWarning: invalid value encountered in sqrt
#   pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
# C:\Users\nixo1\AppData\Local\Temp\ipykernel_22600\3273644669.py:41: RuntimeWarning: invalid value encountered in sqrt
#   pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
# C:\Users\nixo1\AppData\Local\Temp\ipykernel_22600\3273644669.py:41: RuntimeWarning: invalid value encountered in sqrt
#   pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
# C:\Users\nixo1\AppData\Local\Temp\ipykernel_22600\3273644669.py:41: RuntimeWarning: invalid value encountered in sqrt
#   pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
# row
# 11281     2.630000
# 11282     2.700000
# 11283     2.780000
# 11284     2.950000
# 11285     3.110000
#            ...
# 11470    52.200001
# 11471    52.380001
# 11472    52.549999
# 11473    52.750000
# 11474    52.900002
# Name: pressure, Length: 194, dtype: float32
# row
# 11475    52.900002
# 11476    52.860001
# 11477    52.730000
# 11478    52.570000
# 11479    52.410000
#            ...
# 11647     2.500000
# 11648     2.310000
# 11649     2.170000
# 11650     2.040000
# 11651     2.000000
# Name: pressure, Length: 177, dtype: float32
# row
# 11652     2.000000
# 11653     2.060000
# 11654     2.190000
# 11655     2.410000
# 11656     2.770000
#            ...
# 11843    51.450001
# 11844    51.630001
# 11845    51.779999
# 11846    51.880001
# 11847    51.889999
# Name: pressure, Length: 196, dtype: float32
# row
# 11848    51.889999
# 11849    51.790001
# 11850    51.689999
# 11851    51.509998
# 11852    51.270000
#            ...
# 12024     2.180000
# 12025     1.920000
# 12026     1.660000
# 12027     1.470000
# 12028     1.390000
# Name: pressure, Length: 181, dtype: float32
# row
# 12029     1.390000
# 12030     1.420000
# 12031     1.520000
# 12032     1.660000
# 12033     1.820000
#            ...
# 12241    50.950001
# 12242    51.209999
# 12243    51.450001
# 12244    51.570000
# 12245    51.590000
# Name: pressure, Length: 217, dtype: float32
# row
# 12246    51.590000
# 12247    51.529999
# 12248    51.470001
# 12249    51.389999
# 12250    51.290001
#            ...
# 12410     2.190000
# 12411     1.980000
# 12412     1.840000
# 12413     1.760000
# 12414     1.720000
# Name: pressure, Length: 169, dtype: float32
# row
# 12415     1.720000
# 12416     1.790000
# 12417     1.950000
# 12418     2.130000
# 12419     2.460000
#            ...
# 12598    51.279999
# 12599    51.500000
# 12600    51.720001
# 12601    51.820000
# 12602    51.849998
# Name: pressure, Length: 188, dtype: float32
# row
# 12603    51.849998
# 12604    51.730000
# 12605    51.619999
# 12606    51.500000
# 12607    51.310001
#            ...
# 12779     3.220000
# 12780     2.870000
# 12781     2.640000
# 12782     2.380000
# 12783     2.290000
# Name: pressure, Length: 181, dtype: float32
# row
# 12784     2.290000
# 12785     2.340000
# 12786     2.440000
# 12787     2.620000
# 12788     2.790000
#            ...
# 12970    49.970001
# 12971    50.320000
# 12972    50.619999
# 12973    50.790001
# 12974    50.849998
# Name: pressure, Length: 191, dtype: float32
# row
# 12975    50.849998
# 12976    50.779999
# 12977    50.630001
# 12978    50.480000
# 12979    50.410000
#            ...
# 13136     2.910000
# 13137     2.570000
# 13138     2.240000
# 13139     1.950000
# 13140     1.820000
# Name: pressure, Length: 166, dtype: float32
# row
# 13141     1.820000
# 13142     1.870000
# 13143     2.010000
# 13144     2.300000
# 13145     2.570000
#            ...
# 13316    50.959999
# 13317    51.080002
# 13318    51.150002
# 13319    51.310001
# 13320    51.330002
# Name: pressure, Length: 180, dtype: float32
# row
# 13321    51.330002
# 13322    51.220001
# 13323    50.910000
# 13324    50.660000
# 13325    50.459999
#            ...
# 13508     2.590000
# 13509     2.340000
# 13510     2.200000
# 13511     2.090000
# 13512     2.020000
# Name: pressure, Length: 192, dtype: float32
# row
# 13513     2.020000
# 13514     2.070000
# 13515     2.150000
# 13516     2.350000
# 13517     2.680000
#            ...
# 13698    50.259998
# 13699    50.549999
# 13700    50.820000
# 13701    51.020000
# 13702    51.090000
# Name: pressure, Length: 190, dtype: float32
# row
# 13703    51.090000
# 13704    51.090000
# 13705    51.000000
# 13706    50.959999
# 13707    50.910000
#            ...
# 13888     3.180000
# 13889     2.860000
# 13890     2.670000
# 13891     2.530000
# 13892     2.520000
# Name: pressure, Length: 190, dtype: float32
# row
# 13893     2.520000
# 13894     2.670000
# 13895     2.860000
# 13896     3.090000
# 13897     3.290000
#            ...
# 14078    51.439999
# 14079    51.650002
# 14080    51.759998
# 14081    51.779999
# 14082    51.820000
# Name: pressure, Length: 190, dtype: float32
# row
# 14083    51.820000
# 14084    51.820000
# 14085    51.700001
# 14086    51.459999
# 14087    51.150002
#            ...
# 14253     2.670000
# 14254     2.510000
# 14255     2.400000
# 14256     2.440000
# 14257     2.360000
# Name: pressure, Length: 175, dtype: float32
# row
# 14258     2.360000
# 14259     2.450000
# 14260     2.490000
# 14261     2.700000
# 14262     3.030000
#            ...
# 14444    51.660000
# 14445    51.740002
# 14446    51.849998
# 14447    51.880001
# 14448    51.930000
# Name: pressure, Length: 191, dtype: float32
# row
# 14449    51.930000
# 14450    51.830002
# 14451    51.610001
# 14452    51.270000
# 14453    51.009998
#            ...
# 14632     2.750000
# 14633     2.560000
# 14634     2.400000
# 14635     2.260000
# 14636     2.230000
# Name: pressure, Length: 188, dtype: float32
# row
# 14637     2.230000
# 14638     2.260000
# 14639     2.430000
# 14640     2.570000
# 14641     2.830000
#            ...
# 14811    50.020000
# 14812    50.279999
# 14813    50.669998
# 14814    51.000000
# 14815    51.180000
# Name: pressure, Length: 179, dtype: float32
# row
# 14816    51.180000
# 14817    51.169998
# 14818    51.160000
# 14819    51.119999
# 14820    51.060001
#            ...
# 15009     2.880000
# 15010     2.550000
# 15011     2.320000
# 15012     2.220000
# 15013     2.200000
# Name: pressure, Length: 198, dtype: float32
# row
# 15014     2.200000
# 15015     2.200000
# 15016     2.270000
# 15017     2.470000
# 15018     2.720000
#            ...
# 15182    50.369999
# 15183    50.610001
# 15184    50.950001
# 15185    51.180000
# 15186    51.230000
# Name: pressure, Length: 173, dtype: float32
# row
# 15187    51.230000
# 15188    51.080002
# 15189    51.009998
# 15190    51.029999
# 15191    51.080002
#            ...
# 15356     2.890000
# 15357     2.640000
# 15358     2.370000
# 15359     2.270000
# 15360     2.210000
# Name: pressure, Length: 174, dtype: float32
# row
# 15361     2.210000
# 15362     2.290000
# 15363     2.340000
# 15364     2.440000
# 15365     2.540000
#            ...
# 15541    51.480000
# 15542    51.730000
# 15543    51.950001
# 15544    52.130001
# 15545    52.240002
# Name: pressure, Length: 185, dtype: float32
# C:\Users\nixo1\AppData\Local\Temp\ipykernel_22600\3273644669.py:41: RuntimeWarning: invalid value encountered in sqrt
#   pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
# C:\Users\nixo1\AppData\Local\Temp\ipykernel_22600\3273644669.py:41: RuntimeWarning: invalid value encountered in sqrt
#   pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
# C:\Users\nixo1\AppData\Local\Temp\ipykernel_22600\3273644669.py:41: RuntimeWarning: invalid value encountered in sqrt
#   pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
# row
# 15546    52.240002
# 15547    52.189999
# 15548    52.080002
# 15549    52.000000
# 15550    51.889999
#            ...
# 15737     2.900000
# 15738     2.590000
# 15739     2.240000
# 15740     1.980000
# 15741     1.870000
# Name: pressure, Length: 196, dtype: float32
# row
# 15742     1.870000
# 15743     1.880000
# 15744     1.970000
# 15745     1.980000
# 15746     2.060000
#            ...
# 15927    51.400002
# 15928    51.590000
# 15929    51.919998
# 15930    52.180000
# 15931    52.410000
# Name: pressure, Length: 190, dtype: float32
# row
# 15932    52.410000
# 15933    52.380001
# 15934    52.259998
# 15935    52.029999
# 15936    51.889999
#            ...
# 16124     3.320000
# 16125     3.170000
# 16126     3.080000
# 16127     3.050000
# 16128     2.960000
# Name: pressure, Length: 197, dtype: float32
# row
# 16129     2.960000
# 16130     3.040000
# 16131     3.080000
# 16132     3.280000
# 16133     3.510000
#            ...
# 16293    50.139999
# 16294    50.349998
# 16295    50.630001
# 16296    50.919998
# 16297    51.150002
# Name: pressure, Length: 169, dtype: float32
# row
# 16298    51.150002
# 16299    51.150002
# 16300    51.049999
# 16301    50.930000
# 16302    50.919998
#            ...
# 16461     1.970000
# 16462     1.540000
# 16463     1.180000
# 16464          NaN
# 16465          NaN
# Name: pressure, Length: 168, dtype: float32
# row
# 16466          NaN
# 16467          NaN
# 16468          NaN
# 16469          NaN
# 16470          NaN
#            ...
# 16648    49.509998
# 16649    49.709999
# 16650    50.009998
# 16651    50.259998
# 16652    50.430000
# Name: pressure, Length: 187, dtype: float32
# row
# 16653    50.430000
# 16654    50.430000
# 16655    50.279999
# 16656    50.029999
# 16657    49.860001
#            ...
# 16831     2.250000
# 16832     1.960000
# 16833     1.820000
# 16834     1.700000
# 16835     1.690000
# Name: pressure, Length: 183, dtype: float32
# row
# 16836     1.690000
# 16837     1.720000
# 16838     1.870000
# 16839     2.080000
# 16840     2.300000
#            ...
# 17011    49.330002
# 17012    49.580002
# 17013    49.820000
# 17014    50.049999
# 17015    50.110001
# Name: pressure, Length: 180, dtype: float32
# row
# 17016    50.110001
# 17017    50.070000
# 17018    49.889999
# 17019    49.730000
# 17020    49.490002
#            ...
# 17172     2.990000
# 17173     2.720000
# 17174     2.580000
# 17175     2.350000
# 17176     2.230000
# Name: pressure, Length: 161, dtype: float32
# row
# 17177     2.230000
# 17178     2.250000
# 17179     2.370000
# 17180     2.520000
# 17181     2.750000
#            ...
# 17360    49.590000
# 17361    49.880001
# 17362    50.110001
# 17363    50.299999
# 17364    50.369999
# Name: pressure, Length: 188, dtype: float32
# row
# 17365    50.369999
# 17366    50.340000
# 17367    50.139999
# 17368    49.990002
# 17369    49.910000
#            ...
# 17535     2.260000
# 17536     1.980000
# 17537     1.780000
# 17538     1.620000
# 17539     1.560000
# Name: pressure, Length: 175, dtype: float32
# row
# 17540     1.560000
# 17541     1.570000
# 17542     1.660000
# 17543     1.790000
# 17544     2.090000
#            ...
# 17712    49.430000
# 17713    49.540001
# 17714    49.599998
# 17715    49.660000
# 17716    49.689999
# Name: pressure, Length: 177, dtype: float32
# row
# 17717    49.689999
# 17718    49.660000
# 17719    49.459999
# 17720    49.160000
# 17721    48.939999
#            ...
# 17888     3.270000
# 17889     3.250000
# 17890     3.180000
# 17891     3.100000
# 17892     3.050000
# Name: pressure, Length: 176, dtype: float32
# row
# 17893     3.050000
# 17894     3.050000
# 17895     3.110000
# 17896     3.230000
# 17897     3.440000
#            ...
# 18075    48.320000
# 18076    48.529999
# 18077    48.750000
# 18078    48.950001
# 18079    49.040001
# Name: pressure, Length: 187, dtype: float32
# row
# 18080    49.040001
# 18081    48.880001
# 18082    48.740002
# 18083    48.730000
# 18084    48.740002
#            ...
# 18252     2.890000
# 18253     2.600000
# 18254     2.360000
# 18255     2.190000
# 18256     2.050000
# Name: pressure, Length: 177, dtype: float32
# row
# 18257     2.050000
# 18258     2.100000
# 18259     2.230000
# 18260     2.340000
# 18261     2.530000
#            ...
# 18416    47.740002
# 18417    47.919998
# 18418    48.230000
# 18419    48.380001
# 18420    48.410000
# Name: pressure, Length: 164, dtype: float32
# row
# 18421    48.410000
# 18422    48.290001
# 18423    48.320000
# 18424    48.290001
# 18425    48.200001
#            ...
# 18584     2.700000
# 18585     2.560000
# 18586     2.440000
# 18587     2.410000
# 18588     2.390000
# Name: pressure, Length: 168, dtype: float32
# row
# 18589     2.390000
# 18590     2.460000
# 18591     2.630000
# 18592     2.800000
# 18593     3.000000
#            ...
# 18751    47.750000
# 18752    48.110001
# 18753    48.430000
# 18754    48.590000
# 18755    48.610001
# Name: pressure, Length: 167, dtype: float32
# row
# 18756    48.610001
# 18757    48.580002
# 18758    48.570000
# 18759    48.570000
# 18760    48.389999
#            ...
# 18920     3.130000
# 18921     2.980000
# 18922     2.880000
# 18923     2.820000
# 18924     2.800000
# Name: pressure, Length: 169, dtype: float32
# row
# 18925     2.800000
# 18926     2.910000
# 18927     3.020000
# 18928     3.220000
# 18929     3.410000
#            ...
# 19105    49.029999
# 19106    49.119999
# 19107    49.209999
# 19108    49.490002
# 19109    49.599998
# Name: pressure, Length: 185, dtype: float32
# row
# 19110    49.599998
# 19111    49.439999
# 19112    49.110001
# 19113    48.869999
# 19114    48.650002
#            ...
# 19280     3.060000
# 19281     2.780000
# 19282     2.490000
# 19283     2.280000
# 19284     2.180000
# Name: pressure, Length: 175, dtype: float32
# row
# 19285     2.180000
# 19286     2.200000
# 19287     2.280000
# 19288     2.400000
# 19289     2.510000
#            ...
# 19441    47.330002
# 19442    47.590000
# 19443    47.990002
# 19444    48.410000
# 19445    48.619999
# Name: pressure, Length: 161, dtype: float32
# row
# 19446    48.619999
# 19447    48.570000
# 19448    48.509998
# 19449    48.509998
# 19450    48.500000
#            ...
# 19631     2.180000
# 19632     2.040000
# 19633     1.920000
# 19634     1.930000
# 19635     1.900000
# Name: pressure, Length: 190, dtype: float32
# row
# 19636     1.900000
# 19637     1.990000
# 19638     2.130000
# 19639     2.360000
# 19640     2.640000
#            ...
# 19792    48.209999
# 19793    48.330002
# 19794    48.490002
# 19795    48.619999
# 19796    48.730000
# Name: pressure, Length: 161, dtype: float32
# row
# 19797    48.730000
# 19798    48.689999
# 19799    48.500000
# 19800    48.200001
# 19801    47.990002
#            ...
# 19964     2.340000
# 19965     2.220000
# 19966     2.120000
# 19967     2.070000
# 19968     2.040000
# Name: pressure, Length: 172, dtype: float32
# row
# 19969     2.040000
# 19970     2.160000
# 19971     2.340000
# 19972     2.600000
# 19973     2.860000
#            ...
# 20137    48.080002
# 20138    48.160000
# 20139    48.310001
# 20140    48.490002
# 20141    48.509998
# Name: pressure, Length: 173, dtype: float32
# row
# 20142    48.509998
# 20143    48.410000
# 20144    48.230000
# 20145    48.020000
# 20146    47.700001
#            ...
# 20299     3.020000
# 20300     2.800000
# 20301     2.550000
# 20302     2.440000
# 20303     2.350000
# Name: pressure, Length: 162, dtype: float32
# row
# 20304     2.350000
# 20305     2.380000
# 20306     2.430000
# 20307     2.590000
# 20308     2.740000
#            ...
# 20471    48.419998
# 20472    48.470001
# 20473    48.580002
# 20474    48.720001
# 20475    48.880001
# Name: pressure, Length: 172, dtype: float32
# row
# 20476    48.880001
# 20477    48.840000
# 20478    48.730000
# 20479    48.590000
# 20480    48.439999
#            ...
# 20658     3.270000
# 20659     3.050000
# 20660     2.900000
# 20661     2.860000
# 20662     2.810000
# Name: pressure, Length: 187, dtype: float32
# row
# 20663     2.810000
# 20664     2.920000
# 20665     3.040000
# 20666     3.270000
# 20667     3.510000
#            ...
# 20842    48.209999
# 20843    48.270000
# 20844    48.430000
# 20845    48.520000
# 20846    48.590000
# Name: pressure, Length: 184, dtype: float32
# row
# 20847    48.590000
# 20848    48.500000
# 20849    48.320000
# 20850    48.029999
# 20851    47.779999
#            ...
# 21007     3.440000
# 21008     3.150000
# 21009     2.930000
# 21010     2.670000
# 21011     2.530000
# Name: pressure, Length: 165, dtype: float32
# row
# 21012     2.530000
# 21013     2.550000
# 21014     2.650000
# 21015     2.890000
# 21016     3.210000
#            ...
# 21186    47.790001
# 21187    48.040001
# 21188    48.290001
# 21189    48.540001
# 21190    48.619999
# Name: pressure, Length: 179, dtype: float32
# row
# 21191    48.619999
# 21192    48.590000
# 21193    48.540001
# 21194    48.570000
# 21195    48.419998
#            ...
# 21380     2.240000
# 21381     1.910000
# 21382     1.660000
# 21383     1.590000
# 21384     1.520000
# Name: pressure, Length: 194, dtype: float32
# row
# 21385     1.520000
# 21386     1.540000
# 21387     1.630000
# 21388     1.760000
# 21389     1.930000
#            ...
# 21572    47.500000
# 21573    47.740002
# 21574    48.029999
# 21575    48.360001
# 21576    48.529999
# Name: pressure, Length: 192, dtype: float32
# row
# 21577    48.529999
# 21578    48.500000
# 21579    48.389999
# 21580    48.400002
# 21581    48.389999
#            ...
# 21759     2.910000
# 21760     2.780000
# 21761     2.780000
# 21762     2.740000
# 21763     2.710000
# Name: pressure, Length: 187, dtype: float32
# row
# 21764     2.710000
# 21765     2.780000
# 21766     3.010000
# 21767     3.270000
# 21768     3.630000
#            ...
# 21884    32.240002
# 21885    32.500000
# 21886    32.700001
# 21887    32.830002
# 21888    32.840000
# Name: pressure, Length: 125, dtype: float32
# row
# 21889    32.840000
# 21890    32.820000
# 21891    32.740002
# 21892    32.630001
# 21893    32.419998
#            ...
# 22000     2.070000
# 22001     1.840000
# 22002     1.500000
# 22003     1.310000
# 22004     1.010000
# Name: pressure, Length: 116, dtype: float32
# row
# 22005    1.01
# 22006     NaN
# 22007     NaN
# 22008     NaN
# Name: pressure, dtype: float32
# row
# 22009          NaN
# 22010          NaN
# 22011          NaN
# 22012          NaN
# 22013          NaN
#            ...
# 22189    46.439999
# 22190    46.730000
# 22191    47.080002
# 22192    47.389999
# 22193    47.560001
# Name: pressure, Length: 185, dtype: float32
# row
# 22194    47.560001
# 22195    47.490002
# 22196    47.360001
# 22197    47.380001
# 22198    47.480000
#            ...
# 22367     1.370000
# 22368     1.090000
# 22369          NaN
# 22370          NaN
# 22371          NaN
# Name: pressure, Length: 178, dtype: float32
# row
# 22372          NaN
# 22373          NaN
# 22374     1.060000
# 22375     1.240000
# 22376     1.460000
#            ...
# 22532    46.250000
# 22533    46.320000
# 22534    46.400002
# 22535    46.560001
# 22536    46.680000
# Name: pressure, Length: 165, dtype: float32
# row
# 22537    46.680000
# 22538    46.680000
# 22539    46.560001
# 22540    46.369999
# 22541    46.180000
#            ...
# 22696     1.950000
# 22697     1.680000
# 22698     1.510000
# 22699     1.280000
# 22700     1.190000
# Name: pressure, Length: 164, dtype: float32
# row
# 22701     1.190000
# 22702     1.220000
# 22703     1.330000
# 22704     1.570000
# 22705     1.860000
#            ...
# 22858    45.810001
# 22859    46.040001
# 22860    46.330002
# 22861    46.639999
# 22862    46.680000
# Name: pressure, Length: 162, dtype: float32
# row
# 22863    46.680000
# 22864    46.480000
# 22865    46.240002
# 22866    46.180000
# 22867    46.169998
#            ...
# 23037          NaN
# 23038          NaN
# 23039          NaN
# 23040          NaN
# 23041          NaN
# Name: pressure, Length: 179, dtype: float32
# row
# 23042          NaN
# 23043          NaN
# 23044          NaN
# 23045          NaN
# 23046          NaN
#            ...
# 23218    45.779999
# 23219    45.810001
# 23220    45.849998
# 23221    45.840000
# 23222    45.860001
# Name: pressure, Length: 181, dtype: float32
# row
# 23223    45.860001
# 23224    45.759998
# 23225    45.570000
# 23226    45.290001
# 23227    45.040001
#            ...
# 23374     1.260000
# 23375          NaN
# 23376          NaN
# 23377          NaN
# 23378          NaN
# Name: pressure, Length: 156, dtype: float32
# row
# 23379          NaN
# 23380          NaN
# 23381          NaN
# 23382          NaN
# 23383          NaN
#            ...
# 23549    45.150002
# 23550    45.349998
# 23551    45.450001
# 23552    45.639999
# 23553    45.750000
# Name: pressure, Length: 175, dtype: float32
# row
# 23554    45.750000
# 23555    45.639999
# 23556    45.610001
# 23557    45.750000
# 23558    45.689999
#            ...
# 23714     1.190000
# 23715     1.040000
# 23716          NaN
# 23717          NaN
# 23718          NaN
# Name: pressure, Length: 165, dtype: float32
# row
# 23719          NaN
# 23720          NaN
# 23721     1.000000
# 23722     1.220000
# 23723     1.510000
#            ...
# 23905    45.169998
# 23906    45.230000
# 23907    45.360001
# 23908    45.490002
# 23909    45.650002
# Name: pressure, Length: 191, dtype: float32
# row
# 23910    45.650002
# 23911    45.599998
# 23912    45.389999
# 23913    45.110001
# 23914    44.919998
#            ...
# 24077     1.560000
# 24078     1.220000
# 24079     1.030000
# 24080          NaN
# 24081          NaN
# Name: pressure, Length: 172, dtype: float32
# row
# 24082          NaN
# 24083     1.000000
# 24084     1.090000
# 24085     1.330000
# 24086     1.480000
#            ...
# 24241    44.639999
# 24242    44.770000
# 24243    44.939999
# 24244    45.099998
# 24245    45.250000
# Name: pressure, Length: 164, dtype: float32
# row
# 24246    45.250000
# 24247    45.169998
# 24248    45.110001
# 24249    45.040001
# 24250    44.869999
#            ...
# 24404     1.270000
# 24405          NaN
# 24406          NaN
# 24407          NaN
# 24408          NaN
# Name: pressure, Length: 163, dtype: float32
# row
# 24409          NaN
# 24410          NaN
# 24411          NaN
# 24412          NaN
# 24413     1.240000
#            ...
# 24580    45.220001
# 24581    45.290001
# 24582    45.279999
# 24583    45.310001
# 24584    45.340000
# Name: pressure, Length: 176, dtype: float32
# row
# 24585    45.340000
# 24586    45.240002
# 24587    44.970001
# 24588    44.590000
# 24589    44.310001
#            ...
# 24746          NaN
# 24747          NaN
# 24748          NaN
# 24749          NaN
# 24750          NaN
# Name: pressure, Length: 166, dtype: float32
# row
# 24751          NaN
# 24752          NaN
# 24753          NaN
# 24754     1.020000
# 24755     1.260000
#            ...
# 24913    44.770000
# 24914    44.880001
# 24915    45.130001
# 24916    45.490002
# 24917    45.660000
# Name: pressure, Length: 167, dtype: float32
# row
# 24918    45.660000
# 24919    45.560001
# 24920    45.330002
# 24921    45.340000
# 24922    45.419998
#            ...
# 25079     1.140000
# 25080     1.060000
# 25081     1.100000
# 25082     1.010000
# 25083          NaN
# Name: pressure, Length: 166, dtype: float32
# row
# 25084          NaN
# 25085     1.070000
# 25086     1.330000
# 25087     1.580000
# 25088     1.890000
#            ...
# 25243    44.290001
# 25244    44.660000
# 25245    45.040001
# 25246    45.299999
# 25247    45.380001
# Name: pressure, Length: 164, dtype: float32
# row
# 25248    45.380001
# 25249    45.250000
# 25250    45.060001
# 25251    45.049999
# 25252    45.180000
#            ...
# 25406     2.680000
# 25407     2.370000
# 25408     2.070000
# 25409     1.780000
# 25410     1.680000
# Name: pressure, Length: 163, dtype: float32
# row
# 25411     1.680000
# 25412     1.680000
# 25413     1.780000
# 25414     1.940000
# 25415     2.070000
#            ...
# 25582    44.529999
# 25583    44.700001
# 25584    44.939999
# 25585    45.189999
# 25586    45.209999
# Name: pressure, Length: 176, dtype: float32
# row
# 25587    45.209999
# 25588    45.080002
# 25589    44.970001
# 25590    44.950001
# 25591    44.880001
#            ...
# 25754     1.950000
# 25755     1.520000
# 25756     1.160000
# 25757          NaN
# 25758          NaN
# Name: pressure, Length: 172, dtype: float32
# row
# 25759          NaN
# 25760          NaN
# 25761     1.160000
# 25762     1.120000
# 25763     1.150000
#            ...
# 25944    45.000000
# 25945    45.110001
# 25946    45.040001
# 25947    45.099998
# 25948    45.299999
# Name: pressure, Length: 190, dtype: float32
# C:\Users\nixo1\AppData\Local\Temp\ipykernel_22600\3273644669.py:41: RuntimeWarning: invalid value encountered in sqrt
#   pN2 = np.sqrt(9.81 / np.nanmean(df[mld_var]) * np.diff(df[mld_var], prepend=np.nan) / np.diff(df[zvar], prepend=np.nan)) ** 2
# row
# 25949    45.299999
# 25950    45.220001
# 25951    44.959999
# 25952    44.680000
# 25953    44.470001
#            ...
# 26102     1.610000
# 26103     1.340000
# 26104     1.060000
# 26105          NaN
# 26106          NaN
# Name: pressure, Length: 158, dtype: float32
# row
# 26107          NaN
# 26108          NaN
# 26109          NaN
# 26110     1.130000
# 26111     1.480000
#            ...
# 26266    44.150002
# 26267    44.500000
# 26268    44.709999
# 26269    44.889999
# 26270    44.990002
# Name: pressure, Length: 164, dtype: float32
# row
# 26271    44.990002
# 26272    44.950001
# 26273    44.700001
# 26274    44.779999
# 26275    44.939999
#            ...
# 26433     1.540000
# 26434     1.420000
# 26435     1.330000
# 26436     1.220000
# 26437     1.190000
# Name: pressure, Length: 167, dtype: float32
# row
# 26438     1.190000
# 26439     1.280000
# 26440     1.440000
# 26441     1.750000
# 26442     2.010000
#            ...
# 26592    44.509998
# 26593    44.630001
# 26594    44.750000
# 26595    45.009998
# 26596    45.080002
# Name: pressure, Length: 159, dtype: float32
# row
# 26597    45.080002
# 26598    44.970001
# 26599    44.810001
# 26600    44.830002
# 26601    44.709999
#            ...
# 26771     1.820000
# 26772     1.550000
# 26773     1.350000
# 26774     1.260000
# 26775     1.240000
# Name: pressure, Length: 179, dtype: float32
# row
# 26776     1.240000
# 26777     1.270000
# 26778     1.520000
# 26779     1.740000
# 26780     2.030000
#            ...
# 26944    44.049999
# 26945    44.130001
# 26946    44.570000
# 26947    45.049999
# 26948    45.299999
# Name: pressure, Length: 173, dtype: float32
# row
# 26949    45.299999
# 26950    45.250000
# 26951    45.209999
# 26952    45.270000
# 26953    45.189999
#            ...
# 27114     1.270000
# 27115          NaN
# 27116          NaN
# 27117          NaN
# 27118          NaN
# Name: pressure, Length: 170, dtype: float32
# row
# 27119          NaN
# 27120          NaN
# 27121          NaN
# 27122          NaN
# 27123          NaN
#            ...
# 27275    44.720001
# 27276    44.840000
# 27277    44.919998
# 27278    45.110001
# 27279    45.259998
# Name: pressure, Length: 161, dtype: float32
# row
# 27280    45.259998
# 27281    45.200001
# 27282    45.020000
# 27283    44.889999
# 27284    44.810001
#            ...
# 27471     1.050000
# 27472          NaN
# 27473          NaN
# 27474          NaN
# 27475          NaN
# Name: pressure, Length: 196, dtype: float32
# row
# 27476          NaN
# 27477          NaN
# 27478          NaN
# 27479          NaN
# 27480          NaN
#            ...
# 27620    44.990002
# 27621    45.099998
# 27622    45.279999
# 27623    45.380001
# 27624    45.410000
# Name: pressure, Length: 149, dtype: float32
# row
# 27625    45.410000
# 27626    45.389999
# 27627    45.240002
# 27628    44.959999
# 27629    44.610001
#            ...
# 27763     3.900000
# 27764     3.690000
# 27765     3.590000
# 27766     3.470000
# 27767     3.380000
# Name: pressure, Length: 143, dtype: float32
# row
# 27768     3.380000
# 27769     3.410000
# 27770     3.560000
# 27771     3.790000
# 27772     4.140000
#            ...
# 27904    45.049999
# 27905    45.110001
# 27906    45.250000
# 27907    45.400002
# 27908    45.430000
# Name: pressure, Length: 141, dtype: float32
# row
# 27909    45.430000
# 27910    45.279999
# 27911    45.110001
# 27912    44.919998
# 27913    44.759998
#            ...
# 28068     3.220000
# 28069     2.810000
# 28070     2.480000
# 28071     2.170000
# 28072     2.010000
# Name: pressure, Length: 164, dtype: float32
# row
# 28073     2.010000
# 28074     2.050000
# 28075     2.190000
# 28076     2.360000
# 28077     2.500000
#            ...
# 28259    44.070000
# 28260    44.490002
# 28261    44.930000
# 28262    45.189999
# 28263    45.230000
# Name: pressure, Length: 191, dtype: float32
# row
# 28264    45.230000
# 28265    45.099998
# 28266    44.889999
# 28267    44.820000
# 28268    44.840000
#            ...
# 28423     3.250000
# 28424     3.020000
# 28425     2.900000
# 28426     2.780000
# 28427     2.770000
# Name: pressure, Length: 164, dtype: float32
# row
# 28428     2.770000
# 28429     2.820000
# 28430     2.930000
# 28431     3.070000
# 28432     3.270000
#            ...
# 28538    44.560001
# 28539    44.750000
# 28540    44.840000
# 28541    45.040001
# 28542    45.180000
# Name: pressure, Length: 115, dtype: float32
# row
# 28543    45.180000
# 28544    45.160000
# 28545    45.080002
# 28546    45.070000
# 28547    44.959999
#            ...
# 28708     2.820000
# 28709     2.530000
# 28710     2.240000
# 28711     2.150000
# 28712     2.040000
# Name: pressure, Length: 170, dtype: float32
# row
# 28713     2.040000
# 28714     2.060000
# 28715     2.130000
# 28716     2.340000
# 28717     2.460000
#            ...
# 28866    44.590000
# 28867    44.689999
# 28868    44.730000
# 28869    44.880001
# 28870    44.919998
# Name: pressure, Length: 158, dtype: float32
# row
# 28871    44.919998
# 28872    44.730000
# 28873    44.330002
# 28874    43.959999
# 28875    43.700001
#            ...
# 29031     2.930000
# 29032     2.810000
# 29033     2.710000
# 29034     2.550000
# 29035     2.520000
# Name: pressure, Length: 165, dtype: float32
# row
# 29036     2.520000
# 29037     2.610000
# 29038     2.810000
# 29039     2.900000
# 29040     3.050000
#            ...
# 29184    45.160000
# 29185    45.119999
# 29186    45.099998
# 29187    45.189999
# 29188    45.230000
# Name: pressure, Length: 153, dtype: float32
# row
# 29189    45.230000
# 29190    45.049999
# 29191    44.900002
# 29192    44.790001
# 29193    44.580002
#            ...
# 29349     3.040000
# 29350     2.850000
# 29351     2.590000
# 29352     2.490000
# 29353     2.480000
# Name: pressure, Length: 165, dtype: float32
# row
# 29354     2.480000
# 29355     2.550000
# 29356     2.700000
# 29357     3.040000
# 29358     3.320000
#            ...
# 29489    45.060001
# 29490    45.119999
# 29491    45.200001
# 29492    45.330002
# 29493    45.400002
# Name: pressure, Length: 140, dtype: float32
# row
# 29494    45.400002
# 29495    45.279999
# 29496    45.250000
# 29497    45.340000
# 29498    45.250000
#            ...
# 29661     2.390000
# 29662     2.090000
# 29663     1.920000
# 29664     1.800000
# 29665     1.760000
# Name: pressure, Length: 172, dtype: float32
# row
# 29666     1.760000
# 29667     1.760000
# 29668     1.910000
# 29669     2.110000
# 29670     2.390000
#            ...
# 29798    45.000000
# 29799    45.349998
# 29800    45.439999
# 29801    45.540001
# 29802    45.639999
# Name: pressure, Length: 137, dtype: float32
# row
# 29803    45.639999
# 29804    45.630001
# 29805    45.400002
# 29806    45.310001
# 29807    45.320000
#            ...
# 29953     1.740000
# 29954     1.500000
# 29955     1.340000
# 29956     1.220000
# 29957     1.200000
# Name: pressure, Length: 155, dtype: float32
# row
# 29958     1.200000
# 29959     1.230000
# 29960     1.380000
# 29961     1.540000
# 29962     1.710000
#            ...
# 30131    44.650002
# 30132    44.840000
# 30133    45.040001
# 30134    45.060001
# 30135    45.110001
# Name: pressure, Length: 178, dtype: float32
# row
# 30136    45.110001
# 30137    45.029999
# 30138    44.939999
# 30139    44.689999
# 30140    44.509998
#            ...
# 30307     3.030000
# 30308     2.790000
# 30309     2.500000
# 30310     2.350000
# 30311     2.340000
# Name: pressure, Length: 176, dtype: float32
# row
# 30312     2.340000
# 30313     2.440000
# 30314     2.430000
# 30315     2.700000
# 30316     2.790000
#            ...
# 30497    44.439999
# 30498    44.639999
# 30499    44.810001
# 30500    45.020000
# 30501    45.160000
# Name: pressure, Length: 190, dtype: float32
# row
# 30502    45.160000
# 30503    45.070000
# 30504    44.810001
# 30505    44.560001
# 30506    44.570000
#            ...
# 30674     2.400000
# 30675     2.040000
# 30676     1.810000
# 30677     1.620000
# 30678     1.570000
# Name: pressure, Length: 177, dtype: float32
# row
# 30679     1.570000
# 30680     1.610000
# 30681     1.610000
# 30682     1.730000
# 30683     1.940000
#            ...
# 30848    44.349998
# 30849    44.509998
# 30850    44.730000
# 30851    44.880001
# 30852    44.910000
# Name: pressure, Length: 174, dtype: float32
# row
# 30853    44.910000
# 30854    44.779999
# 30855    44.630001
# 30856    44.490002
# 30857    44.360001
#            ...
# 31068     2.390000
# 31069     2.120000
# 31070     1.930000
# 31071     1.890000
# 31072     1.870000
# Name: pressure, Length: 220, dtype: float32
# row
# 31073     1.870000
# 31074     1.960000
# 31075     2.150000
# 31076     2.340000
# 31077     2.600000
#            ...
# 31236    42.880001
# 31237    42.910000
# 31238    42.939999
# 31239    43.209999
# 31240    43.250000
# Name: pressure, Length: 168, dtype: float32
# row
# 31241    43.250000
# 31242    43.070000
# 31243    42.790001
# 31244    42.709999
# ...
# 169178    21.889999
# 169179    22.030001
# 169180    22.080000
# Name: pressure, Length: 75, dtype: float32
# row
# 169181    22.080000
# 169182    22.030001
# 169183    21.969999
# 169184    21.889999
# 169185    21.799999
#             ...
# 169263     4.060000
# 169264     3.860000
# 169265     3.710000
# 169266     3.610000
# 169267     3.570000
# Name: pressure, Length: 87, dtype: float32
# row
# 169268     3.570000
# 169269     3.600000
# 169270     3.680000
# 169271     3.860000
# 169272     4.080000
#             ...
# 169339    21.799999
# 169340    22.010000
# 169341    22.090000
# 169342    22.190001
# 169343    22.290001
# Name: pressure, Length: 76, dtype: float32
# row
# 169344    22.290001
# 169345    22.290001
# 169346    22.150000
# 169347    21.969999
# 169348    21.760000
#             ...
# 169425     4.290000
# 169426     4.090000
# 169427     3.910000
# 169428     3.810000
# 169429     3.750000
# Name: pressure, Length: 86, dtype: float32
# row
# 169430     3.750000
# 169431     3.790000
# 169432     3.870000
# 169433     4.040000
# 169434     4.210000
#             ...
# 169501    21.639999
# 169502    21.870001
# 169503    22.070000
# 169504    22.180000
# 169505    22.240000
# Name: pressure, Length: 76, dtype: float32
# row
# 169506    22.240000
# 169507    22.180000
# 169508    22.080000
# 169509    21.950001
# 169510    21.830000
#             ...
# 169596     3.990000
# 169597     3.800000
# 169598     3.670000
# 169599     3.580000
# 169600     3.570000
# Name: pressure, Length: 95, dtype: float32
# row
# 169601     3.570000
# 169602     3.610000
# 169603     3.740000
# 169604     3.920000
# 169605     4.170000
#             ...
# 169673    21.809999
# 169674    21.950001
# 169675    22.030001
# 169676    22.049999
# 169677    22.080000
# Name: pressure, Length: 77, dtype: float32
# row
# 169678    22.080000
# 169679    21.950001
# 169680    21.750000
# 169681    21.510000
# 169682    21.360001
#             ...
# 169766     4.050000
# 169767     3.880000
# 169768     3.700000
# 169769     3.610000
# 169770     3.560000
# Name: pressure, Length: 93, dtype: float32
# row
# 169771     3.560000
# 169772     3.620000
# 169773     3.730000
# 169774     3.920000
# 169775     4.130000
#             ...
# 169840    21.230000
# 169841    21.500000
# 169842    21.660000
# 169843    21.780001
# 169844    21.809999
# Name: pressure, Length: 74, dtype: float32
# row
# 169845    21.809999
# 169846    21.790001
# 169847    21.660000
# 169848    21.559999
# 169849    21.410000
#             ...
# 169932     4.220000
# 169933     4.040000
# 169934     3.850000
# 169935     3.760000
# 169936     3.690000
# Name: pressure, Length: 92, dtype: float32
# row
# 169937     3.690000
# 169938     3.750000
# 169939     3.820000
# 169940     4.000000
# 169941     4.190000
#             ...
# 170007    21.440001
# 170008    21.530001
# 170009    21.590000
# 170010    21.629999
# 170011    21.709999
# Name: pressure, Length: 75, dtype: float32
# row
# 170012    21.709999
# 170013    21.639999
# 170014    21.490000
# 170015    21.270000
# 170016    21.100000
#             ...
# 170100     4.380000
# 170101     4.190000
# 170102     4.000000
# 170103     3.880000
# 170104     3.800000
# Name: pressure, Length: 93, dtype: float32
# row
# 170105     3.800000
# 170106     3.820000
# 170107     3.890000
# 170108     4.040000
# 170109     4.220000
#             ...
# 170174    20.719999
# 170175    20.900000
# 170176    21.100000
# 170177    21.330000
# 170178    21.350000
# Name: pressure, Length: 74, dtype: float32
# row
# 170179    21.350000
# 170180    21.309999
# 170181    21.230000
# 170182    21.160000
# 170183    20.980000
#             ...
# 170266     4.290000
# 170267     4.130000
# 170268     3.960000
# 170269     3.880000
# 170270     3.800000
# Name: pressure, Length: 92, dtype: float32
# row
# 170271     3.800000
# 170272     3.830000
# 170273     3.880000
# 170274     4.060000
# 170275     4.260000
#             ...
# 170336    20.299999
# 170337    20.530001
# 170338    20.700001
# 170339    20.879999
# 170340    20.900000
# Name: pressure, Length: 70, dtype: float32
# row
# 170341    20.900000
# 170342    20.900000
# 170343    20.850000
# 170344    20.750000
# 170345    20.559999
#             ...
# 170427     4.060000
# 170428     3.890000
# 170429     3.720000
# 170430     3.630000
# 170431     3.580000
# Name: pressure, Length: 91, dtype: float32
# row
# 170432     3.580000
# 170433     3.660000
# 170434     3.740000
# 170435     3.900000
# 170436     4.110000
#             ...
# 170496    20.190001
# 170497    20.400000
# 170498    20.629999
# 170499    20.889999
# 170500    21.010000
# Name: pressure, Length: 69, dtype: float32
# row
# 170501    21.010000
# 170502    20.959999
# 170503    20.870001
# 170504    20.780001
# 170505    20.680000
#             ...
# 170587     4.220000
# 170588     4.060000
# 170589     3.890000
# 170590     3.790000
# 170591     3.710000
# Name: pressure, Length: 91, dtype: float32
# row
# 170592     3.71
# 170593     3.75
# 170594     3.82
# 170595     3.99
# 170596     4.22
# 170597     4.48
# 170598     4.73
# 170599     4.99
# 170600     5.22
# 170601     5.48
# 170602     5.71
# 170603     5.96
# 170604     6.20
# 170605     6.46
# 170606     6.74
# 170607     7.00
# 170608     7.27
# 170609     7.52
# 170610     7.80
# 170611     8.07
# 170612     8.35
# 170613     8.59
# 170614     8.86
# 170615     9.11
# 170616     9.39
# 170617     9.64
# 170618     9.94
# 170619    10.17
# 170620    10.42
# 170621    10.71
# 170622    11.03
# 170623    11.31
# 170624    11.58
# 170625    11.82
# 170626    12.05
# 170627    12.30
# 170628    12.60
# 170629    12.90
# 170630    13.14
# 170631    13.41
# 170632    13.66
# 170633    13.88
# 170634    14.04
# 170635    14.18
# 170636    14.22
# 170637    14.24
# Name: pressure, dtype: float32
# row
# 170638    14.24
# 170639    14.16
# 170640    14.03
# 170641    13.79
# 170642    13.60
#           ...
# 170694     2.06
# 170695     1.83
# 170696     1.64
# 170697     1.40
# 170698     1.20
# Name: pressure, Length: 61, dtype: float32
# row
# 170699          NaN
# 170700          NaN
# 170701          NaN
# 170702          NaN
# 170703          NaN
#             ...
# 170769    19.440001
# 170770    19.740000
# 170771    19.990000
# 170772    20.160000
# 170773    20.200001
# Name: pressure, Length: 75, dtype: float32
# row
# 170774    20.200001
# 170775    20.160000
# 170776    20.010000
# 170777    19.850000
# 170778    19.700001
#             ...
# 170846     2.930000
# 170847     2.770000
# 170848     2.640000
# 170849     2.590000
# 170850     2.580000
# Name: pressure, Length: 77, dtype: float32
# row
# 170851     2.580000
# 170852     2.670000
# 170853     2.810000
# 170854     3.030000
# 170855     3.310000
# 170856     3.640000
# 170857     3.960000
# 170858     4.270000
# 170859     4.610000
# 170860     4.910000
# 170861     5.260000
# 170862     5.610000
# 170863     5.960000
# 170864     6.310000
# 170865     6.630000
# 170866     6.990000
# 170867     7.280000
# 170868     7.630000
# 170869     7.970000
# 170870     8.350000
# 170871     8.690000
# 170872     9.000000
# 170873     9.320000
# 170874     9.610000
# 170875     9.960000
# 170876    10.310000
# 170877    10.690000
# 170878    11.020000
# 170879    11.320000
# 170880    11.600000
# 170881    11.880000
# 170882    12.210000
# 170883    12.550000
# 170884    12.940000
# 170885    13.230000
# 170886    13.550000
# 170887    13.840000
# 170888    14.140000
# 170889    14.480000
# 170890    14.820000
# 170891    15.170000
# 170892    15.450000
# 170893    15.770000
# 170894    16.040001
# 170895    16.340000
# 170896    16.709999
# 170897    17.080000
# 170898    17.410000
# 170899    17.660000
# 170900    17.959999
# 170901    18.299999
# 170902    18.680000
# 170903    18.959999
# 170904    19.280001
# 170905    19.650000
# 170906    19.900000
# 170907    20.080000
# 170908    20.219999
# 170909    20.330000
# Name: pressure, dtype: float32
# row
# 170910    20.330000
# 170911    20.309999
# 170912    20.240000
# 170913    20.059999
# 170914    19.879999
#             ...
# 170989     2.090000
# 170990     1.910000
# 170991     1.740000
# 170992     1.560000
# 170993     1.390000
# Name: pressure, Length: 84, dtype: float32
# row
# 170994          NaN
# 170995          NaN
# 170996          NaN
# 170997          NaN
# 170998          NaN
#             ...
# 171057    19.129999
# 171058    19.350000
# 171059    19.570000
# 171060    19.770000
# 171061    19.879999
# Name: pressure, Length: 68, dtype: float32
# row
# 171062    19.879999
# 171063    19.879999
# 171064    19.700001
# 171065    19.549999
# 171066    19.389999
#             ...
# 171134     2.990000
# 171135     2.830000
# 171136     2.660000
# 171137     2.600000
# 171138     2.590000
# Name: pressure, Length: 77, dtype: float32
# row
# 171139     2.590000
# 171140     2.670000
# 171141     2.790000
# 171142     2.970000
# 171143     3.240000
# 171144     3.530000
# 171145     3.860000
# 171146     4.180000
# 171147     4.520000
# 171148     4.820000
# 171149     5.160000
# 171150     5.480000
# 171151     5.810000
# 171152     6.140000
# 171153     6.470000
# 171154     6.820000
# 171155     7.150000
# 171156     7.490000
# 171157     7.800000
# 171158     8.160000
# 171159     8.470000
# 171160     8.810000
# 171161     9.140000
# 171162     9.490000
# 171163     9.850000
# 171164    10.180000
# 171165    10.520000
# 171166    10.850000
# 171167    11.180000
# 171168    11.450000
# 171169    11.790000
# 171170    12.180000
# 171171    12.570000
# 171172    12.850000
# 171173    13.110000
# 171174    13.390000
# 171175    13.760000
# 171176    14.200000
# 171177    14.550000
# 171178    14.840000
# 171179    15.090000
# 171180    15.450000
# 171181    15.800000
# 171182    16.139999
# 171183    16.440001
# 171184    16.799999
# 171185    17.129999
# 171186    17.459999
# 171187    17.790001
# 171188    18.110001
# 171189    18.469999
# 171190    18.770000
# 171191    19.110001
# 171192    19.430000
# 171193    19.790001
# 171194    20.120001
# 171195    20.430000
# 171196    20.709999
# 171197    20.910000
# 171198    20.950001
# Name: pressure, dtype: float32
# row
# 171199    20.950001
# 171200    20.910000
# 171201    20.840000
# 171202    20.690001
# 171203    20.530001
#             ...
# 171302     2.370000
# 171303     2.170000
# 171304     1.940000
# 171305     1.750000
# 171306     1.530000
# Name: pressure, Length: 108, dtype: float32
# row
# 171307          NaN
# 171308          NaN
# 171309          NaN
# 171310          NaN
# 171311          NaN
#             ...
# 171376    20.120001
# 171377    20.340000
# 171378    20.450001
# 171379    20.540001
# 171380    20.580000
# Name: pressure, Length: 74, dtype: float32
# row
# 171381    20.580000
# 171382    20.520000
# 171383    20.379999
# 171384    20.160000
# 171385    19.879999
#             ...
# 171446     3.370000
# 171447     3.170000
# 171448     2.990000
# 171449     2.850000
# 171450     2.790000
# Name: pressure, Length: 70, dtype: float32
# row
# 171451     2.79
# 171452     2.79
# 171453     2.89
# 171454     3.00
# 171455     3.21
#           ...
# 171511    20.57
# 171512    20.83
# 171513    20.93
# 171514    20.99
# 171515    21.07
# Name: pressure, Length: 65, dtype: float32
# row
# 171516    21.070000
# 171517    21.010000
# 171518    20.809999
# 171519    20.610001
# 171520    20.430000
#             ...
# 171608     2.110000
# 171609     1.910000
# 171610     1.730000
# 171611     1.530000
# 171612     1.310000
# Name: pressure, Length: 97, dtype: float32
# row
# 171613          NaN
# 171614          NaN
# 171615          NaN
# 171616          NaN
# 171617          NaN
#             ...
# 171683    20.059999
# 171684    20.370001
# 171685    20.629999
# 171686    20.740000
# 171687    20.760000
# Name: pressure, Length: 75, dtype: float32
# row
# 171688    20.760000
# 171689    20.590000
# 171690    20.459999
# 171691    20.330000
# 171692    20.129999
#             ...
# 171755     3.210000
# 171756     3.020000
# 171757     2.830000
# 171758     2.700000
# 171759     2.600000
# Name: pressure, Length: 72, dtype: float32
# row
# 171760     2.600000
# 171761     2.620000
# 171762     2.690000
# 171763     2.860000
# 171764     3.080000
# 171765     3.330000
# 171766     3.640000
# 171767     3.930000
# 171768     4.270000
# 171769     4.590000
# 171770     4.920000
# 171771     5.200000
# 171772     5.510000
# 171773     5.800000
# 171774     6.120000
# 171775     6.470000
# 171776     6.800000
# 171777     7.120000
# 171778     7.380000
# 171779     7.720000
# 171780     8.040000
# 171781     8.410000
# 171782     8.710000
# 171783     9.020000
# 171784     9.310000
# 171785     9.660000
# 171786    10.040000
# 171787    10.350000
# 171788    10.690000
# 171789    10.980000
# 171790    11.350000
# 171791    11.650000
# 171792    11.960000
# 171793    12.270000
# 171794    12.630000
# 171795    13.010000
# 171796    13.340000
# 171797    13.620000
# 171798    13.860000
# 171799    14.230000
# 171800    14.620000
# 171801    15.000000
# 171802    15.260000
# 171803    15.500000
# 171804    15.770000
# 171805    16.150000
# 171806    16.540001
# 171807    16.889999
# 171808    17.180000
# 171809    17.420000
# 171810    17.690001
# 171811    18.040001
# 171812    18.440001
# 171813    18.770000
# 171814    19.070000
# 171815    19.299999
# 171816    19.570000
# 171817    19.830000
# 171818    20.090000
# 171819    20.170000
# Name: pressure, dtype: float32
# row
# 171820    20.170000
# 171821    20.100000
# 171822    20.010000
# 171823    19.910000
# 171824    19.780001
#             ...
# 171888     3.160000
# 171889     2.970000
# 171890     2.800000
# 171891     2.700000
# 171892     2.630000
# Name: pressure, Length: 73, dtype: float32
# row
# 171893    2.63
# 171894    2.69
# 171895    2.78
# 171896    2.98
# 171897    3.19
# 171898    3.49
# 171899    3.79
# 171900    4.09
# 171901    4.41
# 171902    4.65
# 171903    4.85
# 171904    4.92
# 171905    4.98
# Name: pressure, dtype: float32
# row
# 171906    4.98
# 171907    4.96
# 171908    4.91
# 171909    4.76
# 171910    4.58
# 171911    4.36
# 171912    4.13
# 171913    3.90
# 171914    3.66
# 171915    3.44
# 171916    3.22
# 171917    3.06
# 171918    2.88
# 171919    2.73
# 171920    2.51
# 171921    2.33
# 171922    2.13
# 171923    1.94
# 171924    1.78
# 171925    1.59
# Name: pressure, dtype: float32
# row
# 171926          NaN
# 171927          NaN
# 171928          NaN
# 171929          NaN
# 171930          NaN
#             ...
# 172018    20.129999
# 172019    20.420000
# 172020    20.540001
# 172021    20.610001
# 172022    20.620001
# Name: pressure, Length: 97, dtype: float32
# row
# 172023    20.620001
# 172024    20.530001
# 172025    20.309999
# 172026    20.200001
# 172027    20.110001
#             ...
# 172115     2.410000
# 172116     2.230000
# 172117     2.080000
# 172118     2.010000
# 172119     2.000000
# Name: pressure, Length: 97, dtype: float32
# row
# 172120     2.000000
# 172121     2.110000
# 172122     2.260000
# 172123     2.500000
# 172124     2.740000
#             ...
# 172191    19.309999
# 172192    19.559999
# 172193    19.879999
# 172194    20.110001
# 172195    20.280001
# Name: pressure, Length: 76, dtype: float32
# row
# 172196    20.280001
# 172197    20.270000
# 172198    20.170000
# 172199    20.059999
# 172200    19.980000
#             ...
# 172284     3.120000
# 172285     2.910000
# 172286     2.690000
# 172287     2.480000
# 172288     2.280000
# Name: pressure, Length: 93, dtype: float32
# row
# 172289          NaN
# 172290          NaN
# 172291          NaN
# 172292          NaN
# 172293          NaN
#             ...
# 172363    19.750000
# 172364    20.030001
# 172365    20.379999
# 172366    20.549999
# 172367    20.610001
# Name: pressure, Length: 79, dtype: float32
# row
# 172368    20.610001
# 172369    20.590000
# 172370    20.559999
# 172371    20.430000
# 172372    20.230000
#             ...
# 172473     1.200000
# 172474     1.060000
# 172475          NaN
# 172476          NaN
# 172477          NaN
# Name: pressure, Length: 110, dtype: float32
# row
# 172479          NaN
# 172480          NaN
# 172481          NaN
# 172482          NaN
# 172483          NaN
#             ...
# 172578    20.230000
# 172579    20.500000
# 172580    20.670000
# 172581    20.780001
# 172582    20.809999
# Name: pressure, Length: 104, dtype: float32
# row
# 172583    20.809999
# 172584    20.660000
# 172585    20.510000
# 172586    20.389999
# 172587    20.209999
#             ...
# 172695          NaN
# 172696          NaN
# 172697          NaN
# 172698          NaN
# 172699          NaN
# Name: pressure, Length: 117, dtype: float32
# row
# 172701          NaN
# 172702          NaN
# 172703          NaN
# 172704          NaN
# 172705          NaN
#             ...
# 172794    20.190001
# 172795    20.410000
# 172796    20.549999
# 172797    20.620001
# 172798    20.660000
# Name: pressure, Length: 98, dtype: float32
# row
# 172799    20.660000
# 172800    20.549999
# 172801    20.330000
# 172802    20.190001
# 172803    20.150000
#             ...
# 172917          NaN
# 172918          NaN
# 172919          NaN
# 172920          NaN
# 172921          NaN
# Name: pressure, Length: 123, dtype: float32
